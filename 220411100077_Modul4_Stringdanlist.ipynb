# %% [markdown]
# # 1	Konsep String
# Tulis ringkasan atau penjelasan hal-hal berikut, dengan kata-kata kalian sendiri :
# 1.	Pengertian variabel dengan type data String, dan berikan contoh
# 2.	Pengaksesan variabel yang bertipe string (jelaskan offset, dan pengaksesan setiap anggota yang terda- pat pada string), dan berikan contoh

# %% [markdown]
# # jawaban :
# 1. variabel dengan type data string adalah sebuah variabel yang diapit oleh tanda petik, baik tanda petik satu (' ') mau pun tanda petik dua (" "), nilai tersebut akan bertype string. conto:
#           3. inpt() in:data="algoritma pemrogrman"
#
#
# 2. pengaksesak variabel yang bertipe data string biasanya kita harus membuat variabel yang berfungsi untuk menampung tipe data string tersebut. variabel tipe data string harus di apit oleh tanda petik satu atau duah juga boleh, lalu kita panggil dengan mengggunakan perintah (print) untuk memanggil variabel tampungan tersebut. String merupakan salah satu tipe data dalam suatu bahasa pemrograman yang terdiri dari beberapa character.Pada tipe data string di python, dikenal offset, yang menunjukkan character ke- dari posisi awal string (yaitu
# offset 0) .Offset ini juga sering disebut dengan index
# Untuk mengakses suatu karakter pada suatu string, dapat dilakukan dengan cara menggunakan 'kurung siku'
# setelah nama variable.
# Misalkan terdapat string : 'Perkuliahan Algoritma Pemrograman', tampilkan character pertama dan kelima dari
# data tersebut yaitu  dedngan  menggunakan kurung siku, [0],akan menampilkan carakter pertama dari data tersebut. apabila ingin menampilkan character pertama dan ke tiga kita menggunakan kurungsikulagi [0:3] contoh:
#           3.  inpt() in:data='Perkuliahan Algoritma Pemrograman'
#                         b=data[0:5]
#                         print(b)
#               out()  in:perkul
#               inpt() in:print(data[6:8])
#               out()  in:iah
#               inpt() in:print(data[9:12])
#               out()  in:an A

# %% [markdown]
# # 2.	Implementasi
# # 2.1	Offset Karakter
#
# Buatlah flowchart untuk mencari indeks/offset dari suatu karakter atau huruf pada suatu kalimat,
#
# dengan ketentuan :
#
# •	kalimat merupakan inputan dari user
#
# •	huruf yang dicari merupakan inputan dari user
#
# •	huruf kapital (huruf besar) dan huruf kecil dianggap sama
#
# Implementasikan flowchart tersebut dengan bahasa Python, dan contoh output sesuai dengan Gambar 1.
#
# ![Screenshot_18.png](data:image/png;base64,...)

# %% [markdown]
# # jawaban :
# ![Main.png](data:image/png;base64,...)

# %%
kalam=input('masukkan kalimat=')
kalcar=input('masukkan huruf yang di cari=')
kalamkabir=kalcar.upper()
kalamShoghir=kalcar.lower()
temp=1
for i in range(len(kalam)):
    if kalamShoghir==kalam[i] or kalamkabir==kalam[i]:
        print('huruf',kalamShoghir,'atau huruf',kalamkabir,'ke-',temp,':','offset-',i)
        temp=temp+1
# Out:
# masukkan kalimat=Universitas Trunojoyo
# masukkan huruf yang di cari=t
# huruf t atau huruf T ke- 1 : offset- 8
# huruf t atau huruf T ke- 2 : offset- 12

# %% [markdown]
# # 2.2 Konversi Bilangan
# Buatlah code menu untuk konversi bilangan dari Desimal ke Biner dan sebaliknya, yaitu :
#
# •	pilihan 1:  Desimal ke Biner (input Desimal, output Biner)
#
# •	pilihan 2: Biner ke Desimal (input Biner, output Desimal)
#
# •	menu lagi, apakah user akan mengulangi operasi ataukah berhenti Contoh output dapat dilihat
#
# pada Gambar 2.

# %%
# jawaban
stop=False
while not(stop):
    print("""menu
    Tekan 1 untuk konversi Desimal ke Biner
    Tekan 2 untuk konversi Biner ke desimal
    """)
    p=int(input('masukkan pilihan anda='))
    if p==1:
        r=int(input('masukkan Desiml='))
        hasil=r
        strBiner=''
        while hasil!=0:
            w=hasil%2
            hasil=hasil//2
            strBiner=str(w)+strBiner
        print('bilangan binner','=',strBiner)
    if p==2:
        file=0
        count=0
        data=input('masukkan bilangan biner=')
        for i in range (len(data)-1,-1,-1):
            file=file+int(data[i])*(2**count)
            count=count+1
        print('Bilangan desimal=',file)
    g=input('ingin mengulang oprasi kembali (y/t)?')
    print(20*'===')
    if g=='y':
        stop=False
    elif g=='t':
        stop=True
    else:
        stop=True
# Out:
# menu
#     Tekan 1 untuk konversi Desimal ke Biner
#     Tekan 2 untuk konversi Biner ke desimal
#
# masukkan pilihan anda=1
# masukkan Desiml=456
# bilangan binner = 111001000
# ingin mengulang oprasi kembali (y/t)?y
# ...
# menu
#     Tekan 1 untuk konversi Desimal ke Biner
#     Tekan 2 untuk konversi Biner ke desimal
#
# masukkan pilihan anda=2
# masukkan bilangan biner=111001000
# Bilangan desimal= 456
# ingin mengulang oprasi kembali (y/t)?y
# ...
# menu
#     Tekan 1 untuk konversi Desimal ke Biner
#     Tekan 2 untuk konversi Biner ke desimal
#
# masukkan pilihan anda=2
# masukkan bilangan biner=11110001101
# Bilangan desimal= 1933
# ingin mengulang oprasi kembali (y/t)?y
# ...
# menu
#     Tekan 1 untuk konversi Desimal ke Biner
#     Tekan 2 untuk konversi Biner ke desimal
#
# masukkan pilihan anda=1
# masukkan Desiml=1933
# bilangan binner = 11110001101
# ingin mengulang oprasi kembali (y/t)?t
# ...

# %% [markdown]
# # 2.3	Fungsi Matematika
# Terdapat fungsi matematika berikut ini :
#
# ![Screenshot_14.png](data:image/png;base64,...)
#
#
# dimana x merupakan list dengan n buah anggota numerik dengan indeks dimulai dari 1. Contoh output dari fungsi matematika tersebut dapat dilihat pada Gambar 3
#
#
#
# ![Screenshot_15.png](data:image/png;base64,...)
#
#
# ![Screenshot_16.png](data:image/png;base64,...)

# %%
#jawaban
x=[10,10,5,10,10]
print('x=',x)
n=len(x)
total=0
fx=0
for i in range(n):
    total=total+x[i]
    jamak=1/n*total
for i in  range(n):
    fx=fx+x[i]-jamak
print('xbar=',jamak)  
print('fx=',fx)

print(23*'===')

x=[2,4,6,8,10]
print('x=',x)
n=len(x)
total=0
fx=0
for i in range(n):
    total=total+x[i]
    jamak=1/n*total
for i in  range(n):
    fx=fx+x[i]-jamak
print('xbar=',jamak)  
print('fx=',fx)
# Out:
# x= [10, 10, 5, 10, 10]
# xbar= 9.0
# fx= 0.0
# ...
# x= [2, 4, 6, 8, 10]
# xbar= 6.0
# fx= 0.0
