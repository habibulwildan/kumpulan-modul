# %% [markdown]
# # 1 Fungsi Rekursif
# ## 1.1 Penjumlahan List
# Buatlah Fungsi Rekursif untuk menjumlahkan semua anggota yang terdapat pada suatu list, dengan
# tampilan seperti yang ditunjukkan pada Gambar 1

# %%
# jawaban
def sumList(temp):
    if len (temp)==1:
        return temp[-1]
    else:
        print(temp[:-1],"+",temp[-1])
        return temp[-1]+sumList(temp[:-1])

# %%
dataList=[10,5,8,9,18,1,9,2,30]
sumList(dataList)
# Out:
# [10, 5, 8, 9, 18, 1, 9, 2] + 30
# [10, 5, 8, 9, 18, 1, 9] + 2
# [10, 5, 8, 9, 18, 1] + 9
# [10, 5, 8, 9, 18] + 1
# [10, 5, 8, 9] + 18
# [10, 5, 8] + 9
# [10, 5] + 8
# [10] + 5
# 92

# %% [markdown]
# ## 1.2 Penjumlahan Karakter Angka di dalam String
# Buatlah Fungsi Rekursif untuk menjumlahan setiap digit karakter yang berupa angka di dalam sebuah
# string. [Hint] Gunakan fungsi string.isdigit() untuk pengecakan apakah karakter di dalam string adalah
# angka. Tampilan output dari fungsi ini dapat dilihat pada Gambar2

# %%
#jawaban
def sumStringDigit (angka):
    if angka.isdigit():
        if len(angka)==1:
            return angka[0]
        else:
            return int(angka[0])+int(sumStringDigit(angka[1:]))
            
    else:
        return "tidak dapat dikonversi ke angka"
        

strNum="42357"
print("Total penjumlahan dari digit'",strNum,"'adalah",sumStringDigit(strNum))
# Out:
# Total penjumlahan dari digit' 42357 'adalah 21

# %% [markdown]
# # 2 List2D
# ## 2.1 Create List 2D
# Buatlah fungsi untuk membuat list 2D, dimana setiap anggotanya merupakan inputan dari user. Buatlah
# code agar memiliki tampilan seperti pada Gambar 3, dan return value berupa list2D.

# %%
# jawaban
def createList2D (a,b):
    tampung=[]
    for i in range(a):
        bk=[]
        for c in range(b):
            temp=int(input(f"list [{i},{c}] : "))
            bk.append(temp)
        tampung.append(bk)
    return tampung

# %%
mat1=createList2D(2,3)
print(mat1)
# Out:
# list [0,0] : 1
# list [0,1] : 3
# list [0,2] : 5
# list [1,0] : 2
# list [1,1] : 4
# list [1,2] : 6
# [[1, 3, 5], [2, 4, 6]]

# %% [markdown]
# ## 2.2 Maks List 2D
# Buatlah fungsi untuk mencari nilai maksimum dari suatu list 2D, dengan ketentuan sebagai berikut :
# 1. Terdapat dua Parameter yaitu list dan jenis maksimum
# 2. Jenis maksimum hanya ada dua nilai : baris dan kolom
#
# ![Screenshot_20221122_153057.png](data:image/png;base64,...)
#
# ![Screenshot_20221122_153308.png](data:image/png;base64,...)
#
#     (a) jenis=’baris’, yaitu mencari nilai maksimal di setiap kolom dari seluruh baris
#
#     (b) jenis=’kolom’, yaitu mencari nilai maksimal di setiap baris dari seluruh kolo
# 3. return value berupa list yang berisi nilai maksimal
# Buat code sehingga menghasilkan tampilan seperti yang ditunjukkan pada Gambar 4
# ![Screenshot_20221122_153816.png](data:image/png;base64,...)
#
# ![Screenshot_20221122_154233.png](data:image/png;base64,...)

# %%
#jawaban
def maxList2D(data,jnsmax):
    list1=[]
    list2=[]
    if jnsmax=="baris":
        for c in range(len(data[0])):
            maks=0
            for i in range(len(data)):
                if data[i][c]>maks:
                    maks=data[i][c]
            list1.append(maks)
        return list1
    elif jnsmax=="kolom":
        for w in range(len(data)):
            mask1=0
            for r in range(len(data[0])):
                if data[w][r]>mask1:
                    mask1=data[w][r]
            list2.append(mask1)
        return list2
data=[[1,5,8,3,11,2,],[5,2,9,2,9,0],[10,1,3,14,0,20]]
maskList=maxList2D(data,"kolom")
print(data)
print(maskList)
# Out:
# [[1, 5, 8, 3, 11, 2], [5, 2, 9, 2, 9, 0], [10, 1, 3, 14, 0, 20]]
# [11, 9, 20]
