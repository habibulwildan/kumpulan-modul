# %% [markdown]
# # 1. konsep seleksi dan iterasi
# tulis ringkasn dan penjelasan hal-hal berikut,dengan kata kata kalian sendiri:
# >1. terdapat tiga syntax percabangan didalam python, yaitu if,if else,if elif else. jelaskan perbedaan ketiganya, dan tuliskan contoh code masing masind syntax.
# >2. terdpat dua syntax perulangan didalam python, yaitu for dan while. jelaskan perbedaan keduanya dan tuliskan contoh code masing-masing syntax.

# %% [markdown]
# ### jawab:
# 1. if=fungsi if adalah program akan men eksekusi pernytaan hanya jika ekspresi pengujinya bernilai true, bisa disimpulkan bahwa apabila kita ingin mencabangkan sebuah bilangan menggunakan if saja,maka kita hanya bisa mendapatkan kan percabangan satu kali,artinya bahwa bilangan atau nilai yang kita masukkan bernilai true maka bilangan tersebut di kerjakan, jika bilangan tersebut bernilai false maka bilangan atau nilai tersebut tidak diker jakan contoh cod:
#
# > in () input: if a==b:
#
#                      print('benar')
# > if else= fungsi dimana jika kondisi salah,kita masih memiliki pilihan lain yang bisa dilakukan pengujinya,dengan katalain apabila bilangan atau angka yang kita masukkan bernilai false maka angka tersebut masi bisa di jalankan, contoh code:
#
#  > in () input: if kota=='lamongan':
#
#                   print('asal lamongan')
#
#                 else:
#                   print('bukan asal lamongan')
# > if elif else= elif merupakan singkatan dari else if.fungsi ini membuat kita di perkenankan memeriksa beberapa ekspresi. jika kondisi if false, maka sistem akan mengecek kondisi ini di elif, jika semuah kondisi elif salah, maka pernyataan else lah yang akan di eksekusi.contoh code:
#  > in ()input: if kota=='lamongan':
#
#                   print('asal lamongan')
#                 elif kota=='bojonegoro':
#                   print('bukan asal lamongan tapi dekat lamongan')
#
#                 else:
#                   print('bukan asal lamongan')
#
#
# 2. for=perulangan yang biasanya digunakan untuk mengulang kode yang sudah dikethui banyak perulanganya. contohcode:
#
#   > in ()input: for i in range(5):
#
#                     print(i)
#
#   while= perulangan yang masih belum di tentukan berapa banyak perulangan nya,dapat disimpulkan bahwasannya while ini belum ditentukan banyak bilangan yang di ulang,apabila bilangan itu bernilai true makabilangan tersebut akan dikerjakan terus sampek bilangan tersebut bernilai flse,gmn caranya mengubah menjadi false,kita harus menambahi stoping condutionya. conto code:
#   > in ()input: w=0
#                 while w<=6:
#                   print(w)
#                   w=w+1

# %% [markdown]
# # 2. implementasi
# ### 2.1 Bilangan prima
# butla flowchart(tidak harus menggunakan flogorithm)dari penentuan apakah suatu bilangan (inputan dari user) adalah bilangan prima.implementasikan flowchart yang sudah dibuat (bukan generate dari flowgorithm) dengan menggunkan bahasa python, sehingga menghasilkan output seperti contoh-contoh yang terdapat pada gambar 1.

# %% [markdown]
# ## jawab
# ![prima.png](data:image/png;base64,...)

# %%
w=0
bilangan=int(input('masukkan bilangan='))
for i in range(1,bilangan+1):
  if bilangan%i==0:
    w=w+1
if w==2:
  print(bilangan,'adalah bilangan prima')
else:
  print(bilangan,'bukan prima.','memiliki jumlah faktor pembagi',w)
# Out:
# masukkan bilangan=24
# 24 bukan prima. memiliki jumlah faktor pembagi 8

# %% [markdown]
# # 2.2	Segitiga siku-siku
# Buatlah code untuk menentukan apakah suatu segitiga (diketahui adalah panjang sisi dari segita), merupakan suatu segitiga siku-siku, dengan ketentuan sebagai berikut :
# >1.	Terdapat tiga inputan, yaitu sisi-sisi segitiga (sisi pertama, sisi kedua, dan sisi ketiga)
# >2.	Segitiga siku-siku merupakan segitiga dimana kuadrat sisi miring merupakan penjumlahan dari kuadrat dari masing-masing sisi siku-siku, yaitu c2 = a2 + b2 (c adalah sisi miring, a dan b merupakan sisi siku- siku). Contoh ilustrasi segitiga siku-siku ini dapat dilihat pada Gambar 2
# >3.	Contoh inputan dan Output dari code ini dapat dilihat pada Gambar 3
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
# jawab
a=int(input('masukkan sisi pertama a='))
b=int(input('masukkan sisi keduah b='))
c=int(input('masukkan sisi ketiga c='))

h=c**2
miring=c
w=a**2+b**2
siku1=a
siku2=b

if h==w:
  print('segitiga siku siku dengan sisi siku siku adalah',siku1,'dan',siku2,'.','serta sisi miring adalah',miring)
else:
  print('sisi',{a,b,c},'bukan segitiga siku siku')
# Out:
# masukkan sisi pertama a=15
# masukkan sisi keduah b=9
# masukkan sisi ketiga c=12
# sisi {9, 12, 15} bukan segitiga siku siku

# %% [markdown]
# # 2.3	Iterasi di dalam Iterasi
# Buatlah code untuk menampilkan penomoran daftar isi, seperti contoh pada 4. Dengan inputan dari user berupa jumlah bab dan sub bab dalam setiap bab. [Hint : Buatlah iterasi di dalam iterasi]

# %%
#jawab
b=int(input('masukkan jumlah bab='))
w=int(input('masukkan jumlah subbab di setiap bab='))
for i in range(1,b+1):
  print(i,'.',"    ")
  for x in range(1,w+1):
    print("   ",i,'.',x)
# Out:
# masukkan jumlah bab=4
# masukkan jumlah subbab di setiap bab=3
# 1 .
#     1 . 1
#     1 . 2
#     1 . 3
# 2 .
#     2 . 1
#     2 . 2
#     2 . 3
# 3 .
#     3 . 1
#     3 . 2
#     3 . 3
# 4 .
#     4 . 1
#     4 . 2
#     4 . 3

# %% [markdown]
# # 2.4	Menu
# Buatlah code untuk membuat menu, dimana setiap menu melakukan operasi yang berbeda :
#
# Menu :
#
# >•	Tekan 1 untuk operasi perhitungan luas lingkaran (input adalah jari-jari)
#
# >•	Tekan 2 untuk operasi perhitungan luas persegi panjang (input adalah panjang dan lebar)
#
# >•	Tekan 3 untuk operasi perhitungan luas segitiga (input adalah alas dan tinggi)
# Tambahkan pilihan bagi user, apakah ingin mengulangi operasi kembali ataukah tidak, jika ‘y’, maka
#
#
#  ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# > tampilkan menu kembali dan lakukan operasi sesuai pilihan dari user. Jika user memilih ‘t’ maka operasi berhenti. Contoh output dari code tersebut dapat dilihat pada Gambar 5
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %%
# jawab:
berhenti=False
while not(berhenti):
  print('menu')
  print('''                                                                                 
  tekan 1 untuk oprasi perhitungan luas lingkaran(input adalah jari-jari)
  tekan 2 untuk oprasi perhitungan luas persegi panjang(input adalah panjang dan lebar)
  tekan 3 untuk oprasi perhitungan luas segitiga(input adalah alas dan tinggi)
  ''')
  w=int(input('masukkan pilihan anda='))
  if w==1:
    pi=3.14
    r=float(input('masukkan angka='))
    L=pi*r**2
    print(L)
  elif w==2:
    p=int(input('masukkan panjang='))
    l=int(input('masukkan lebar='))
    luas=p*l
    print(luas)
  else:
    a=int(input('masukkan alas='))
    t=int(input('masukkan tinggi='))
    l=1/2*a*t
    print(l)

  l=input('lanjut y/t?')
  if l=='t':
    berhenti=True
  else:
    berhenti=False
# Out:
# menu
#
#   tekan 1 untuk oprasi perhitungan luas lingkaran(input adalah jari-jari)
#   tekan 2 untuk oprasi perhitungan luas persegi panjang(input adalah panjang dan lebar)
#   tekan 3 untuk oprasi perhitungan luas segitiga(input adalah alas dan tinggi)
#
# masukkan pilihan anda=1
# masukkan angka=5
# 78.5
# lanjut y/t?y
# menu
#
#   tekan 1 untuk oprasi perhitungan luas lingkaran(input adalah jari-jari)
#   tekan 2 untuk oprasi perhitungan luas persegi panjang(input adalah panjang dan lebar)
#   tekan 3 untuk oprasi perhitungan luas segitiga(input adalah alas dan tinggi)
#
# masukkan pilihan anda=3
# masukkan alas=5
# masukkan tinggi=7
# 17.5
# lanjut y/t?t
